# %% [markdown]
# # Imports

# %%
import os
import pickle

import pandas as pd
import numpy as np
import seaborn as sns

from utils import CustomCleaner, get_random_base
from scipy.stats import uniform

from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV, StratifiedKFold
from sklearn.preprocessing import PowerTransformer, TargetEncoder, LabelEncoder, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report, fbeta_score, make_scorer
from sklearn.multiclass import OneVsOneClassifier

from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from cuml.svm import SVC as cumlSVC # Using GPU acceleration for model selection, final model will be vanilla sklearn, if SVC is chosen

import warnings; warnings.filterwarnings('ignore')

# %% [markdown]
# # Load data

# %%
df = pd.read_csv(os.path.join('..', 'clean_data', 'outliers.csv'), index_col=0)
df.head()
# Out:
#    encounter_id country  patient_id             race  gender      age weight  \
# 0        533253     USA       70110        Caucasian  Female  [70-80)      ?
# 2        634063     USA    80729253        Caucasian  Female  [60-70)      ?
# 3        890610     USA     2919042  AfricanAmerican    Male  [60-70)      ?
# 4        654194     USA    84871971        Caucasian  Female  [70-80)      ?
# 5        269878     USA      279288        Caucasian  Female  [50-60)      ?
#
#   payer_code  outpatient_visits_in_previous_year  \
# 0          ?                                   0
# 2          ?                                   0
# 3         MC                                   0
# 4         HM                                   1
# 5          ?                                   0
#
#    emergency_visits_in_previous_year  ...  secondary_diagnosis  \
# 0                                  0  ...                  276
# 2                                  0  ...                  135
# 3                                  0  ...                  562
# 4                                  0  ...                  599
# 5                                  0  ...                  250
#
#   additional_diagnosis number_diagnoses  glucose_test_result a1c_test_result  \
# 0                  466                8                  NaN             NaN
# 2                  250                6                  NaN             NaN
# 3                  455                5                  NaN             NaN
# 4                  428                9                  NaN             NaN
# 5                  244                3                  NaN            Norm
#
#   change_in_meds_during_hospitalization  prescribed_diabetes_meds  \
# 0                                    No                        No
# 2                                    Ch                       Yes
# 3                                    No                        No
# 4                                    No                        No
# 5                                    No                        No
#
#                    medication  readmitted_binary  readmitted_multiclass
# 0                          []                 No               >30 days
# 2  ['glimepiride', 'insulin']                 No                     No
# 3                          []                 No                     No
# 4                          []                 No               >30 days
# 5                          []                 No               >30 days
#
# [5 rows x 31 columns]

# %% [markdown]
# # Preproc

# %%
cleaner = CustomCleaner()
df_clean = cleaner.fit_transform(df)

# %%
df_clean = df_clean.drop(columns=['country', 'weight', 'glucose_test_result', 'a1c_test_result'])

# %%
num_cols = df_clean.select_dtypes(include=np.number).drop(columns=['encounter_id', 'patient_id']).columns.to_list()

# %%
cat_cols = df_clean.select_dtypes(exclude=np.number).drop(columns=['readmitted_binary', 'readmitted_multiclass']).columns

# %%
X = df_clean.drop(columns=['readmitted_binary', 'readmitted_multiclass', 'encounter_id', 'patient_id'])
y = df_clean.readmitted_multiclass

label = LabelEncoder()
y = label.fit_transform(y)

# %%
label.classes_
# Out:
# array(['<30 days', '>30 days', 'No'], dtype=object)

# %%
pd.Series(y).value_counts()
# Out:
# 2    37320
# 1    24218
# 0     7712
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)
cv = StratifiedKFold(n_splits=5)

# %% [markdown]
# ## Pipeline

# %%
cat_pipe = Pipeline([
    ('encoder', TargetEncoder(target_type='continuous'))
])

num_pipe = Pipeline([
    ('imputer', SimpleImputer()),
    ('transformer', PowerTransformer()),
    ('scaler', MinMaxScaler())
])

preproc_pipe = ColumnTransformer([
    ('cat', cat_pipe, cat_cols),
    ('num', num_pipe, num_cols)
], remainder='drop')

preproc_pipe
# Out:
# ColumnTransformer(transformers=[('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   TargetEncoder(target_type='continuous'))]),
#                                  Index(['race', 'gender', 'payer_code', 'admission_type', 'medical_specialty',
#        'discharge_disposition', 'admission_source', 'primary_diagnosis',
#        'secondary_diagnosis', 'additional_diagnosis',
#        'change_in_meds_during_hospitalization', 'prescribed_diabetes...
#                                   'emergency_visits_in_previous_year',
#                                   'inpatient_visits_in_previous_year',
#                                   'average_pulse_bpm',
#                                   'length_of_stay_in_hospital',
#                                   'number_lab_tests', 'non_lab_procedures',
#                                   'number_of_medications', 'number_diagnoses',
#                                   'number_diab_meds',
#                                   'number_visits_per_patient',
#                                   'n_medication_per_day', 'n_lab_tests_per_day',
#                                   'prop_inpatient', 'prop_outpatient',
#                                   'prop_emergency'])])

# %%
preproc_pipe.fit(X_train, y_train)
X_train = np.float32(preproc_pipe.transform(X_train))
X_test = np.float32(preproc_pipe.transform(X_test))

# %% [markdown]
# # Model

# %%
scorer = make_scorer(fbeta_score, beta=5, average='weighted') # Weighted f1 score, giving more importance to recall than precision

# %% [markdown]
# ## Base model

# %%
y_base = get_random_base(y_test)

# %%
print(classification_report(y_test, y_base, target_names=label.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     <30 days       0.11      0.11      0.11      1928
#     >30 days       0.35      0.35      0.35      6055
#           No       0.54      0.54      0.54      9330
#
#     accuracy                           0.43     17313
#    macro avg       0.34      0.34      0.34     17313
# weighted avg       0.43      0.43      0.43     17313

# %% [markdown]
# ## SGD

# %%
# OvR by default
sgd_ovr = SGDClassifier(n_jobs=-1, class_weight='balanced', max_iter=1000)

# %%
cross_val_score(sgd_ovr, X_train, y_train, scoring=scorer, cv=cv, n_jobs=-1).mean()
# Out:
# 0.6586436769791918

# %%
# OvO
sgd_ovo = OneVsOneClassifier(SGDClassifier(n_jobs=-1, class_weight='balanced', max_iter=1000))

# %%
cross_val_score(sgd_ovo, X_train, y_train, scoring=scorer, cv=cv, n_jobs=-1).mean()
# Out:
# 0.5616991138524614

# %% [markdown]
# ## SVC

# %%
# OvR
svc_ovr = cumlSVC(class_weight='balanced', multiclass_strategy='ovr')

# %%
cross_val_score(svc_ovr, X_train, y_train, scoring=scorer, cv=cv, n_jobs=-1).mean()
# Out:
# 0.6383964018342555

# %%
# OvO
svc_ovo = cumlSVC(class_weight='balanced', multiclass_strategy='ovo')

# %%
cross_val_score(svc_ovo, X_train, y_train, scoring=scorer, cv=cv, n_jobs=-1).mean()
# Out:
# 0.5753314600314486

# %% [markdown]
# # Hypertuning

# %% [markdown]
# ## SVC

# %%
rand_params = {
    'multiclass_strategy': ['ovo', 'ovr'],
    'C': uniform(0.05, 50),
    'kernel': ['poly', 'rbf', 'linear', 'sigmoid'],
    'degree': [2, 3, 4],
    'gamma': ['auto', 'scale'],
    'coef0': uniform(0, 1) 
}

# %%
rand_svc = RandomizedSearchCV(cumlSVC(class_weight='balanced'), rand_params, n_iter=300, scoring=scorer, cv=cv, n_jobs=-1, verbose=2)
rand_svc.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# [C
degree=4, gamma=scale, kernel=linear, multiclass_strategy=ovo; total time=   0.4s
# [CV] END C=14.880271716593974, coef0=0.04009515830408972, degree=2, gamma=scale, kernel=linear, multiclass_strategy=ovr; total time=   0.4s
# [CV] END C=41.375627958901894, coef0=0.25235789145869425, degree=2, gamma=auto, kernel=poly, multiclass_strategy=ovr; total time=   0.4s
# [CV] END C=3.7929480386871495, coef0=0.5290050297237453, degree=3, gamma=scale, kernel=poly, multiclass_strategy=ovo; total time=   0.4s
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#                    estimator=SVC(), n_iter=300, n_jobs=-1,
#                    param_distributions={'C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f3ac8fbaf50>,
#                                         'coef0': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f3ac8f9d090>,
#                                         'degree': [2, 3, 4],
#                                         'gamma': ['auto', 'scale'],
#                                         'kernel': ['poly', 'rbf', 'linear',
#                                                    'sigmoid'],
#                                         'multiclass_strategy': ['ovo', 'ovr']},
#                    scoring=make_scorer(fbeta_score, beta=5, average=weighted),
#                    verbose=2)

# %%
rand_svc.best_params_
# Out:
# {'C': 44.02009983416125,
#  'coef0': 0.7809176129012151,
#  'degree': 3,
#  'gamma': 'auto',
#  'kernel': 'rbf',
#  'multiclass_strategy': 'ovr'}

# %%
y_pred = rand_svc.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.24      0.31      0.27      1928
#            1       0.56      0.45      0.50      6055
#            2       0.75      0.81      0.78      9330
#
#     accuracy                           0.62     17313
#    macro avg       0.52      0.52      0.52     17313
# weighted avg       0.63      0.62      0.62     17313

# %% [markdown]
# ## SGD OvR

# %%
rand_params = {
    'loss': ['hinge', 'log_loss', 'squared_hinge', 'perceptron', 'modified_huber'],
    'penalty': ['l1', 'l2', 'elasticnet', None],
    'l1_ratio': uniform(0, 1),
    'alpha': uniform(0.00001, 1),
    'learning_rate': ['optimal', 'invscaling', 'adaptive', 'constant'],
    'eta0': uniform(0, 1),
    'epsilon': uniform(0, 1),
    'power_t': uniform(-1, 1)
}

# %%
rand_sgd = RandomizedSearchCV(sgd_ovr, rand_params, n_iter=300, scoring=scorer, cv=cv, n_jobs=-1, verbose=1)
rand_sgd.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#                    estimator=SGDClassifier(class_weight='balanced', n_jobs=-1),
#                    n_iter=300, n_jobs=-1,
#                    param_distributions={'alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f3ac8fdca90>,
#                                         'epsilon': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f3cc...
#                                         'l1_ratio': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f3ccb8d4a90>,
#                                         'learning_rate': ['optimal',
#                                                           'invscaling',
#                                                           'adaptive',
#                                                           'constant'],
#                                         'loss': ['hinge', 'log_loss',
#                                                  'squared_hinge', 'perceptron',
#                                                  'modified_huber'],
#                                         'penalty': ['l1', 'l2', 'elasticnet',
#                                                     None],
#                                         'power_t': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f3ccb8d6680>},
#                    scoring=make_scorer(fbeta_score, beta=5, average=weighted),
#                    verbose=1)

# %%
rand_sgd.best_params_
# Out:
# {'alpha': 0.8058197939273687,
#  'epsilon': 0.11859171477367458,
#  'eta0': 0.28303250561455784,
#  'l1_ratio': 0.23253005867598175,
#  'learning_rate': 'adaptive',
#  'loss': 'hinge',
#  'penalty': None,
#  'power_t': -0.6849907138495789}

# %%
rand_sgd.best_score_
# Out:
# 0.660577862850626

# %%
y_pred = rand_sgd.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.32      0.01      0.02      1928
#            1       0.55      0.60      0.58      6055
#            2       0.73      0.83      0.77      9330
#
#     accuracy                           0.66     17313
#    macro avg       0.53      0.48      0.46     17313
# weighted avg       0.62      0.66      0.62     17313

# %% [markdown]
# ## SGD OvO

# %%
rand_params = {
    'estimator__loss': ['hinge', 'log_loss', 'squared_hinge', 'perceptron', 'modified_huber'],
    'estimator__penalty': ['l1', 'l2', 'elasticnet', None],
    'estimator__l1_ratio': uniform(0, 1),
    'estimator__alpha': uniform(0.00001, 1),
    'estimator__learning_rate': ['optimal', 'invscaling', 'adaptive', 'constant'],
    'estimator__eta0': uniform(0, 1),
    'estimator__epsilon': uniform(0, 1),
    'estimator__power_t': uniform(-1, 1)
}

# %%
rand_sgd_ovo = RandomizedSearchCV(sgd_ovo, rand_params, n_iter=300, scoring=scorer, cv=cv, n_jobs=-1, verbose=1)
rand_sgd_ovo.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /home/vsn/.pyenv/versions/3.10.6/envs/mestrado/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#                    estimator=OneVsOneClassifier(estimator=SGDClassifier(class_weight='balanced',
#                                                                         n_jobs=-1)),
#                    n_iter=300, n_jobs=-1,
#                    param_distributions={'estimator__alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f3ccb8d5c00>,
#                                         'estimator__epsilon': <scipy.stats._dist...
#                                         'estimator__learning_rate': ['optimal',
#                                                                      'invscaling',
#                                                                      'adaptive',
#                                                                      'constant'],
#                                         'estimator__loss': ['hinge', 'log_loss',
#                                                             'squared_hinge',
#                                                             'perceptron',
#                                                             'modified_huber'],
#                                         'estimator__penalty': ['l1', 'l2',
#                                                                'elasticnet',
#                                                                None],
#                                         'estimator__power_t': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f3ccb698ac0>},
#                    scoring=make_scorer(fbeta_score, beta=5, average=weighted),
#                    verbose=1)

# %%
rand_sgd_ovo.best_params_
# Out:
# {'estimator__alpha': 0.307520189653321,
#  'estimator__epsilon': 0.9935271890314104,
#  'estimator__eta0': 0.03761823466274239,
#  'estimator__l1_ratio': 0.4330466987065259,
#  'estimator__learning_rate': 'optimal',
#  'estimator__loss': 'modified_huber',
#  'estimator__penalty': 'elasticnet',
#  'estimator__power_t': -0.8886132269824396}

# %%
rand_sgd_ovo.best_score_
# Out:
# 0.6306738121606362

# %%
y_pred = rand_sgd_ovo.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1928
#            1       0.55      0.61      0.58      6055
#            2       0.72      0.83      0.77      9330
#
#     accuracy                           0.66     17313
#    macro avg       0.43      0.48      0.45     17313
# weighted avg       0.58      0.66      0.62     17313

# %% [markdown]
# # Final model and results

# %%
# Best params found by RandomSearchCV, using as scoring the fbeta.
# The fbeta is a modified f1 scorer, in which we can give weight to the recall agains the precision.

best_params = {'C': 44.02009983416125,
               'coef0': 0.7809176129012151,
               'degree': 3,
               'gamma': 'auto',
               'kernel': 'rbf',
               'decision_function_shape': 'ovr'}

# %%
model_path = os.path.join('..', 'pipelines', 'models', 'best_model.pkl')
if not os.path.exists(model_path):
    final_model = SVC(class_weight='balanced', **best_params)
    final_model.fit(X_train, y_train)
    with open(model_path, 'wb') as f:
        pickle.dump(final_model, f)
else:
    with open(model_path, 'rb') as f:
        final_model = pickle.load(f)

final_model
# Out:
# SVC(C=44.02009983416125, class_weight='balanced', coef0=0.7809176129012151,
#     gamma='auto')

# %%
y_pred = final_model.predict(X_test)

# %%
print('BEST MODEL METRICS')
print('_' * 55)
print(classification_report(y_test, y_pred, target_names=label.classes_))
# Out:
# BEST MODEL METRICS
# _______________________________________________________
#               precision    recall  f1-score   support
#
#     <30 days       0.23      0.47      0.31      1928
#     >30 days       0.57      0.33      0.42      6055
#           No       0.75      0.80      0.77      9330
#
#     accuracy                           0.60     17313
#    macro avg       0.52      0.53      0.50     17313
# weighted avg       0.63      0.60      0.60     17313

# %%
print('DUMMY MODEL METRICS')
print('_' * 55)
print(classification_report(y_test, y_base, target_names=label.classes_))
# Out:
# DUMMY MODEL METRICS
# _______________________________________________________
#               precision    recall  f1-score   support
#
#     <30 days       0.11      0.11      0.11      1928
#     >30 days       0.35      0.35      0.35      6055
#           No       0.54      0.54      0.54      9330
#
#     accuracy                           0.43     17313
#    macro avg       0.34      0.34      0.34     17313
# weighted avg       0.43      0.43      0.43     17313
#
# [W] [15:02:38.788973] SVC with the linear kernel can be much faster using the specialized solver provided by LinearSVC. Consider switching to LinearSVC if tranining takes too long.
# [CV] END C=44.796137684290905, coef0=0.20361310715799952, degree=3, gamma=auto, kernel=linear, multiclass_strategy=ovr; total time=   0.7s
# [CV] END C=18.35449817932975, coef0=0.7085329114514962, degree=2, gamma=auto, kernel=linear, multiclass_strategy=ovo; total time=   0.2s
# [CV] END C=12.631229830946861, coef0=0.2906985188080662, degree=2, gamma=auto, kernel=linear, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=44.802464853478696, coef0=0.2456859198577458, degree=3, gamma=scale, kernel=linear, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=27.969364929843277, coef0=0.011493998091130497, degree=2, gamma=scale, kernel=rbf, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=0.8548296559506785, coef0=0.5916694786939024, degree=2, gamma=scale, kernel=rbf, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=9.95588372900193, coef0=0.5041217409291033, degree=4, gamma=scale, kernel=linear, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=10.059001598350093, coef0=0.6035503226263242, degree=4, gamma=auto, kernel=linear, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=20.28085924466372, coef0=0.9042411759985958, degree=3, gamma=scale, kernel=poly, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=7.9627526222636575, coef0=0.9669706894452917, degree=4, gamma=scale, kernel=linear, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=23.203938345718306, coef0=0.5941215633607057, degree=2, gamma=auto, kernel=poly, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=45.27162255150759, coef0=0.5408224248417614, degree=3, gamma=scale, kernel=rbf, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=24.232651732396118, coef0=0.09225881679482717, degree=2, gamma=auto, kernel=poly, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=43.06501470697362, coef0=0.3379657883561722, degree=3, gamma=scale, kernel=rbf, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=14.7113398967892, coef0=0.2778414593614391, degree=3, gamma=auto, kernel=rbf, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=46.838105225167446, coef0=0.9172657892774109, degree=3, gamma=scale, kernel=poly, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=24.0220873711017, coef0=0.5597152189077517, degree=4, gamma=scale, kernel=rbf, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=37.94973892155598, coef0=0.4659267902379042, degree=3, gamma=auto, kernel=sigmoid, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=48.17700472904854, coef0=0.03036589886691199, degree=3, gamma=scale, kernel=sigmoid, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=43.096838057750084, coef0=0.29479168112041554, degree=3, gamma=scale, kernel=linear, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=15.035877108615221, coef0=0.743066951293277, degree=3, gamma=auto, kernel=linear, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=6.910281103533788, coef0=0.987933005486144, degree=4, gamma=auto, kernel=linear, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=16.58075043123761, coef0=0.42178492901327336, degree=2, gamma=auto, kernel=poly, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=7.048433303612988, coef0=0.3660715062104334, degree=4, gamma=scale, kernel=poly, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=49.446303141247554, coef0=0.882553545333806, degree=4, gamma=scale, kernel=rbf, multiclass_strategy=ovo; total time=   0.4s
# [CV] END C=18.24586061031616, coef0=0.42039816991808965, degree=4, gamma=scale, kernel=poly, multiclass_strategy=ovr; total time=   0.4s
# [CV] END C=26.862154782616834, coef0=0.990664276209516, degree=2, gamma=auto, kernel=poly, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=39.211830893898814, coef0=0.16623673432622943, degree=4, gamma=auto, kernel=sigmoid, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=32.699184344465884, coef0=0.9013669551855075, degree=4, gamma=auto, kernel=sigmoid, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=14.137120550227523, coef0=0.020922508449172983, degree=3, gamma=scale, kernel=rbf, multiclass_strategy=ovo; total time=   0.4s
# [CV] END C=29.275067518382404, coef0=0.9290005601858916, degree=3, gamma=auto, kernel=rbf, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=35.063767212825674, coef0=0.11969302463268172, degree=3, gamma=auto, kernel=linear, multiclass_strategy=ovr; total time=   0.4s
# [CV] END C=18.492818080946737, coef0=0.6761395106276353, degree=2, gamma=scale, kernel=linear, multiclass_strategy=ovr; total time=   0.4s
# [CV] END C=4.16106275489011, coef0=0.5139895290736943, degree=2, gamma=scale, kernel=linear, multiclass_strategy=ovo; total time=   0.4s
# [CV] END C=43.01320016941445, coef0=0.6792688095180104, degree=4, gamma=scale, kernel=linear, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=31.883249368581367, coef0=0.01614708931690101, degree=4, gamma=auto, kernel=rbf, multiclass_strategy=ovo; total time=   0.4s
# [CV] END C=31.545638239139628, coef0=0.8572277761092626, degree=4, gamma=scale, kernel=poly, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=1.4539333117516262, coef0=0.7540373331058103, degree=3, gamma=auto, kernel=poly, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=12.702724604686473, coef0=0.7223858326295339, degree=3, gamma=auto, kernel=linear, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=24.304737129522604, coef0=0.15796936688831342, degree=2, gamma=scale, kernel=poly, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=23.053205155089792, coef0=0.9003976034492817, degree=3, gamma=scale, kernel=sigmoid, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=50.00792823093972, coef0=0.9455702224825, degree=2, gamma=scale, kernel=sigmoid, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=48.11533552001587, coef0=0.7535584648983648, degree=2, gamma=auto, kernel=rbf, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C
gamma=auto, kernel=rbf, multiclass_strategy=ovo; total time=   0.4s
# [CV] END C=23.93669231776785, coef0=0.6378876504383988, degree=3, gamma=scale, kernel=linear, multiclass_strategy=ovo; total time=   0.5s
# [CV] END C=43.919030500893285, coef0=0.15229182344944925, degree=2, gamma=auto, kernel=sigmoid, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=28.803332629260805, coef0=0.3768872312327556, degree=2, gamma=scale, kernel=linear, multiclass_strategy=ovr; total time=   0.3s
# [W] [15:02:38.788860] SVC with the linear kernel can be much faster using the specialized solver provided by LinearSVC. Consider switching to LinearSVC if tranining takes too long.
# [CV] END C=49.7384542488941, coef0=0.9579255380338034, degree=3, gamma=scale, kernel=linear, multiclass_strategy=ovo; total time=   0.7s
# [CV] END C=35.41879143208285, coef0=0.9261113990252384, degree=4, gamma=auto, kernel=sigmoid, multiclass_strategy=ovr; total time=   0.2s
# [CV] END C=12.631229830946861, coef0=0.2906985188080662, degree=2, gamma=auto, kernel=linear, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=44.802464853478696, coef0=0.2456859198577458, degree=3, gamma=scale, kernel=linear, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=47.148016036090475, coef0=0.7162410758582926, degree=4, gamma=scale, kernel=rbf, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=3.555961942110458, coef0=0.41751435512533575, degree=3, gamma=scale, kernel=rbf, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=49.22324071911831, coef0=0.3836751896638031, degree=4, gamma=scale, kernel=rbf, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=15.988620641191936, coef0=0.8770936928839944, degree=3, gamma=auto, kernel=sigmoid, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=47.94445918792435, coef0=0.6443477326989603, degree=2, gamma=auto, kernel=linear, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=41.96386979629254, coef0=0.07188854577666381, degree=4, gamma=scale, kernel=linear, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=33.67595645087491, coef0=0.5510964901454743, degree=2, gamma=scale, kernel=sigmoid, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=8.511764624993269, coef0=0.3657637692936796, degree=2, gamma=scale, kernel=sigmoid, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=21.590345683893826, coef0=0.23430855882799884, degree=4, gamma=auto, kernel=sigmoid, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=33.60973015949638, coef0=0.2040107334983281, degree=2, gamma=scale, kernel=linear, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=0.4296271130566131, coef0=0.4626529502819551, degree=2, gamma=auto, kernel=rbf, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=1.0839888583655477, coef0=0.7435752395472947, degree=2, gamma=auto, kernel=poly, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=16.382307926380197, coef0=0.8072245287076781, degree=3, gamma=auto, kernel=sigmoid, multiclass_strategy=ovo; total time=   6.3s
# [CV] END C=40.41003721707516, coef0=0.196436321184706, degree=3, gamma=scale, kernel=poly, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=34.04898730699768, coef0=0.4611198655446763, degree=2, gamma=scale, kernel=linear, multiclass_strategy=ovo; total time=   0.4s
# [CV] END C=11.162932692726914, coef0=0.8675922995143336, degree=2, gamma=scale, kernel=linear, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=12.354319352842353, coef0=0.2055578325014591, degree=3, gamma=auto, kernel=poly, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=7.346608544810878, coef0=0.5191947746974575, degree=2, gamma=scale, kernel=rbf, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=5.7401252242429255, coef0=0.4470746711567485, degree=3, gamma=auto, kernel=rbf, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=40.09152336527341, coef0=0.6083300050889512, degree=2, gamma=scale, kernel=poly, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=20.84561027136431, coef0=0.4329960466951073, degree=4, gamma=scale, kernel=rbf, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=30.591651349554827, coef0=0.5814384541051185, degree=2, gamma=auto, kernel=linear, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=16.378061548455747, coef0=0.052575078352643745, degree=2, gamma=scale, kernel=poly, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=26.797208920964266, coef0=0.7095457725755755, degree=3, gamma=scale, kernel=rbf, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=23.81857565139494, coef0=0.762729837145415, degree=4, gamma=auto, kernel=poly, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=15.309655778499838, coef0=0.17778977006534635, degree=3, gamma=auto, kernel=linear, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=33.38470600444656, coef0=0.08237168619209012, degree=4, gamma=scale, kernel=rbf, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=41.96918800224797, coef0=0.7111698769545639, degree=4, gamma=auto, kernel=linear, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=48.23123944670975, coef0=0.4737246360207472, degree=2, gamma=scale, kernel=linear, multiclass_strategy=ovo; total time=   0.3s
# [CV] END C=18.475270859021737, coef0=0.2484778183044022, degree=3, gamma=auto, kernel=poly, multiclass_strategy=ovr; total time=   0.3s
# [CV] END C=39.180952296216994, coef0=0.1624328268849593, degree=4, gamma=scale, kernel=rbf, multiclass_strategy=ovr; total time=   0.4s
# [CV] END C=12.066095729384113, coef0=0.2385829595593334, degree=4, gamma=scale, kernel=linear, multiclass_strategy=ovo; total time=   0.4s
# [CV] END C=4.062216106050176, coef0=0.794461277805103, degree=4, gamma=scale, kernel=rbf, multiclass_strategy=ovo; total time=   0.4s
# [CV] END C=12.13272069210824, coef0=0.08337900828256262, degree=3, gamma=scale, kernel=poly, multiclass_strategy=ovr; total time=   0.4s
# [CV] END C=40.97937000717893, coef0=0.3655964436266771, degree=2, gamma=auto, kernel=sigmoid, multiclass_strategy=ovr; total time=   0.4s
# [CV] END C=47.086063019321294, coef0=0.7534391407208088, degree=4, gamma=auto, kernel=linear, multiclass_strategy=ovo; total time=   0.3s
